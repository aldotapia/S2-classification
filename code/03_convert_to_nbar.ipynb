# %%
import os
from sen2nbar.nbar import nbar_SAFE

# %% [markdown]
# # test with one scene

# %%
root_path = '/Volumes/TOSHIBA EXT/Msc/Scenes'

# list folders from external drive
paths = os.listdir(root_path)

# %%
paths = [val for val in paths if not os.path.exists(os.path.join(root_path,val,'NBAR'))]

# %%
[val for val in paths if os.path.exists(os.path.join(root_path,val,'NBAR'))]
# Out:
# ['S2B_MSIL2A_20211129T143719_N0301_R096_T19JBF_20211129T190617.SAFE',
#  'S2A_MSIL2A_20211114T143731_N0301_R096_T19JBF_20211114T190616.SAFE',
#  'S2B_MSIL2A_20220227T143729_N0400_R096_T19JCG_20220227T195718.SAFE',
#  'S2A_MSIL2A_20211224T143731_N0301_R096_T19JCG_20211224T185953.SAFE',
#  'S2B_MSIL2A_20220207T143719_N0400_R096_T19JCF_20220207T184738.SAFE',
#  'S2A_MSIL2A_20220503T143731_N0400_R096_T19JCG_20220503T214318.SAFE',
#  'S2A_MSIL2A_20220113T143731_N0301_R096_T19JBF_20220113T190151.SAFE',
#  'S2B_MSIL2A_20210622T143729_N0300_R096_T19JCF_20210622T184502.SAFE',
#  'S2A_MSIL2A_20210528T143731_N0300_R096_T19JCG_20210528T182550.SAFE',
#  'S2B_MSIL2A_20210831T143729_N0301_R096_T19JCG_20210831T191302.SAFE',
#  'S2A_MSIL2A_20210428T143721_N0300_R096_T19JCG_20210428T184640.SAFE',
#  'S2B_MSIL2A_20210930T143729_N0301_R096_T19JCF_20210930T191645.SAFE',
#  'S2B_MSIL2A_20211229T143719_N0301_R096_T19JCG_20211229T190535.SAFE',
# ...

# %%
for path in paths:
    # convert to nbar
    nbar_SAFE(os.path.join(root_path, path), to_int=True)
# Out:
# /Users/aldotapia/miniforge3/envs/msc/lib/python3.11/site-packages/sen2nbar/metadata.py:91: RuntimeWarning: Mean of empty slice
#   bands_dict[key][angle] = np.nanmean(
# Processing B02:   0%|          | 0/9 [00:00<?, ?it/s]/Users/aldotapia/miniforge3/envs/msc/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:186: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# Processing B03:  11%|█         | 1/9 [00:24<03:17, 24.64s/it]/Users/aldotapia/miniforge3/envs/msc/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:186: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# Processing B04:  22%|██▏       | 2/9 [00:51<02:59, 25.70s/it]/Users/aldotapia/miniforge3/envs/msc/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:186: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# ...
