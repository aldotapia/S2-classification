# %%
import os
import time
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.random import set_seed
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import Sequential
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

# %%
# check if GPU is available
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# sgd = SGD(lr=0.01, momentum=0.9, decay=0.0001, nesterov=True)

# %%
path = 'C:/Users/promm/Documents/S2-classification/Data/'

# load train, validation and test data
train = pd.read_csv(os.path.join(path, 'train.csv'))
val = pd.read_csv(os.path.join(path, 'val.csv'))
test = pd.read_csv(os.path.join(path, 'test.csv'))

# %%
# create a dictionary to convert labels to integers
labels = train['specie'].unique()
labels_dict = dict(zip(labels, range(len(labels))))

# %%
labels
# Out:
# array(['almond', 'avocado', 'barren', 'barren shadowed', 'forage',
#        'industrial grape', 'lemon', 'mandarin', 'olive', 'orange',
#        'riverside vegetation', 'short cycle crop', 'table grape', 'urban',
#        'walnut', 'water'], dtype=object)

# %%
# convert labels to integers
train['specie'] = train['specie'].map(labels_dict)
val['specie'] = val['specie'].map(labels_dict)
test['specie'] = test['specie'].map(labels_dict)

# %%
train_labels = to_categorical(train['specie'])
val_labels = to_categorical(val['specie'])
test_labels_expanded = to_categorical(test['specie'])
test_labels = test['specie']
train = train.drop(['ID','specie'], axis=1)
val = val.drop(['ID','specie'], axis=1)
ids = test['ID']
test = test.drop(['ID','specie'], axis=1)

# %%
mpath = 'C:/Users/promm/Documents/S2-classification/models'

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.figsize'] = 10,10

# %%
def get_model(ts=train.shape[1], tl=train_labels.shape[1], conv = False, conv_layers=[], dense_layers=[], dropout=0.15, lr=0.01):
    """


    Args:
        conv (bool, optional): _description_. Defaults to False.
        conv_layers (list, optional): _description_. Defaults to [].
        dense_layers (list, optional): _description_. Defaults to [].
        dropout (float, optional): _description_. Defaults to 0.5.
        lr (float, optional): _description_. Defaults to 0.001.
        batch_size (int, optional): _description_. Defaults to 32.
        epochs (int, optional): _description_. Defaults to 100.
        patience (int, optional): _description_. Defaults to 10.
        verbose (int, optional): _description_. Defaults to 1.
    """

    model = Sequential()
    if conv:
        model.add(Input(shape=(ts,1)))

        for layer in conv_layers:
            model.add(Conv1D(layer, 3, activation='relu'))
            model.add(BatchNormalization())
            model.add(MaxPooling1D(2))
        model.add(Flatten())
    else:
        model.add(Input(shape=(ts,)))
    for layer in dense_layers:
        model.add(Dense(layer, activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))
    model.add(Dense(tl, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
conv = [False, False, False, False, False, False, False, False, False, False, False, False, False, False,
        True, True, True, True, True, True, True, True, True, True, True, True]
conv_layers = [[], [], [], [], [], [], [], [], [], [], [], [], [], [],
        [64], [64], [64], [32], [32], [32], [64,32], [64,32], [64,32], [32,16], [32,16], [32,16],]
dense_layers = [[64], [128], [256], [512,256], [512,128], [128,64], [128,32], [256,128], [256,64], [256,32], [256,256,128], [128,64,32], [256,128,64], [256,128,32],
                [64], [64,32], [128,64],[64], [64,32], [128,64],[64], [64,32], [128,64],[64], [64,32], [128,64]]

# %%
kind = 'all'

flag = True

for i in range(len(conv)):

    if flag:
        if conv[i]:
            # do things
            train = train.to_numpy().reshape(train.shape[0], train.shape[1],1)
            val = val.to_numpy().reshape(val.shape[0], val.shape[1],1)
            test = test.to_numpy().reshape(test.shape[0], test.shape[1],1)
            flag = False


    model = get_model(conv=conv[i], conv_layers=conv_layers[i], dense_layers=dense_layers[i])
    model.summary()
    model_name = f'model_{kind}_{i}.h5'

    np.random.seed(123)
    random.seed(123)
    set_seed(123)

    model_checkpoint_callback = ModelCheckpoint(os.path.join(mpath, model_name), monitor='val_loss', mode='min', save_best_only=True)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=40, mode='min')
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='min')

    start = time.time()
    history = model.fit(train, train_labels, epochs=600, batch_size=8, validation_data=(val, val_labels),
                        callbacks=[model_checkpoint_callback, early_stopping_callback, reduce_lr_callback], verbose = 0)
    end = time.time()
    print(f'{end - start} seconds')

    test_loss, test_acc = model.evaluate(test, test_labels_expanded)
    y_pred = model.predict(test)
    # get the index of the max probability
    y_pred = np.argmax(y_pred, axis=1)

    # plot loss and accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.legend()
    plt.savefig(os.path.join(mpath, f'model_history_{kind}_{i}.png'), dpi=300)
    plt.close()

    # confusion matrix
    cm = confusion_matrix(test_labels, y_pred)
    # plot confusion matrix
    plt.imshow(cm, cmap='CMRmap_r')
    plt.xlabel("Predicted labels")
    plt.ylabel("True labels")
    # add ticks values from labels
    tick_marks = np.arange(len(labels))
    # rotate x ticks to 90 degrees
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)
    plt.title('Confusion matrix ')
    plt.colorbar()
    plt.savefig(os.path.join(mpath, f'cm_{kind}_{i}.png'), dpi=300)
    plt.close()

    # dataframe from y_pred, test_labels
    df = pd.DataFrame({'FID':ids, 'y_pred': y_pred, 'y_obs': test_labels})
    df.to_csv(os.path.join(mpath, f'pred_{kind}_{i}.csv'), index=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                4224
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 5,520
# Trainable params: 5,392
# Non-trainable params: 128
# _________________________________________________________________
# 94.90552043914795 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8687
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 128)               8448
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 16)                2064
#
# =================================================================
# Total params: 11,024
# Trainable params: 10,768
# Non-trainable params: 256
# _________________________________________________________________
# 93.66249060630798 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8813
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               16896
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 16)                4112
#
# =================================================================
# Total params: 22,032
# Trainable params: 21,520
# Non-trainable params: 512
# _________________________________________________________________
# 150.98347234725952 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2993 - accuracy: 0.9146
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               33792
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 16)                4112
#
# =================================================================
# Total params: 172,304
# Trainable params: 170,768
# Non-trainable params: 1,536
# _________________________________________________________________
# 68.4210000038147 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 3.7447 - accuracy: 0.9000
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               33792
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 128)               65664
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 16)                2064
#
# =================================================================
# Total params: 104,080
# Trainable params: 102,800
# Non-trainable params: 1,280
# _________________________________________________________________
# 113.62171363830566 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9104
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               8448
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 18,512
# Trainable params: 18,128
# Non-trainable params: 384
# _________________________________________________________________
# 140.43461513519287 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9146
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               8448
#
#  batch_normalization_9 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 32)                4128
#
#  batch_normalization_10 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_17 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 13,744
# Trainable params: 13,424
# Non-trainable params: 320
# _________________________________________________________________
# 161.1853165626526 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2704 - accuracy: 0.9083
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 256)               16896
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_19 (Dense)            (None, 128)               32896
#
#  batch_normalization_12 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 16)                2064
#
# =================================================================
# Total params: 53,392
# Trainable params: 52,624
# Non-trainable params: 768
# _________________________________________________________________
# 155.73384404182434 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2290 - accuracy: 0.9146
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 256)               16896
#
#  batch_normalization_13 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 64)                16448
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 35,664
# Trainable params: 35,024
# Non-trainable params: 640
# _________________________________________________________________
# 106.31307983398438 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2094 - accuracy: 0.9271
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 256)               16896
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 32)                8224
#
#  batch_normalization_16 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 32)                0
#
#  dense_26 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 26,800
# Trainable params: 26,224
# Non-trainable params: 576
# _________________________________________________________________
# 137.0096092224121 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.9229
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 256)               16896
#
#  batch_normalization_17 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 256)               65792
#
#  batch_normalization_18 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 128)               32896
#
#  batch_normalization_19 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 16)                2064
#
# =================================================================
# Total params: 120,208
# Trainable params: 118,928
# Non-trainable params: 1,280
# _________________________________________________________________
# 102.6549654006958 seconds
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3085 - accuracy: 0.8917
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_31 (Dense)            (None, 128)               8448
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 64)                8256
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 64)                0
#
#  dense_33 (Dense)            (None, 32)                2080
#
#  batch_normalization_22 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_34 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 20,208
# Trainable params: 19,760
# Non-trainable params: 448
# _________________________________________________________________
# 150.80931544303894 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2778 - accuracy: 0.8979
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 256)               16896
#
#  batch_normalization_23 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  dense_36 (Dense)            (None, 128)               32896
#
#  batch_normalization_24 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_24 (Dropout)        (None, 128)               0
#
#  dense_37 (Dense)            (None, 64)                8256
#
#  batch_normalization_25 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_25 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 60,880
# Trainable params: 59,984
# Non-trainable params: 896
# _________________________________________________________________
# 175.00056886672974 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2294 - accuracy: 0.9146
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_39 (Dense)            (None, 256)               16896
#
#  batch_normalization_26 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_26 (Dropout)        (None, 256)               0
#
#  dense_40 (Dense)            (None, 128)               32896
#
#  batch_normalization_27 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_27 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 32)                4128
#
#  batch_normalization_28 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 32)                0
#
#  dense_42 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 56,112
# Trainable params: 55,280
# Non-trainable params: 832
# _________________________________________________________________
# 202.68936443328857 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2454 - accuracy: 0.9125
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 63, 64)            256
#
#  batch_normalization_29 (Bat  (None, 63, 64)           256
#  chNormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 31, 64)           0
#  )
#
#  flatten (Flatten)           (None, 1984)              0
#
#  dense_43 (Dense)            (None, 64)                127040
#
#  batch_normalization_30 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_29 (Dropout)        (None, 64)                0
#
#  dense_44 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 128,848
# Trainable params: 128,592
# Non-trainable params: 256
# _________________________________________________________________
# 138.07071900367737 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1668 - accuracy: 0.9396
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 63, 64)            256
#
#  batch_normalization_31 (Bat  (None, 63, 64)           256
#  chNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 31, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1984)              0
#
#  dense_45 (Dense)            (None, 64)                127040
#
#  batch_normalization_32 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_30 (Dropout)        (None, 64)                0
#
#  dense_46 (Dense)            (None, 32)                2080
#
#  batch_normalization_33 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_47 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 130,544
# Trainable params: 130,224
# Non-trainable params: 320
# _________________________________________________________________
# 135.68027138710022 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.9417
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 63, 64)            256
#
#  batch_normalization_34 (Bat  (None, 63, 64)           256
#  chNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, 31, 64)           0
#  1D)
#
#  flatten_2 (Flatten)         (None, 1984)              0
#
#  dense_48 (Dense)            (None, 128)               254080
#
#  batch_normalization_35 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_32 (Dropout)        (None, 128)               0
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  batch_normalization_36 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_33 (Dropout)        (None, 64)                0
#
#  dense_50 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 264,656
# Trainable params: 264,144
# Non-trainable params: 512
# _________________________________________________________________
# 87.4397919178009 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1505 - accuracy: 0.9438
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 63, 32)            128
#
#  batch_normalization_37 (Bat  (None, 63, 32)           128
#  chNormalization)
#
#  max_pooling1d_3 (MaxPooling  (None, 31, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (None, 992)               0
#
#  dense_51 (Dense)            (None, 64)                63552
#
#  batch_normalization_38 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_34 (Dropout)        (None, 64)                0
#
#  dense_52 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 65,104
# Trainable params: 64,912
# Non-trainable params: 192
# _________________________________________________________________
# 96.73236393928528 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1937 - accuracy: 0.9229
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 63, 32)            128
#
#  batch_normalization_39 (Bat  (None, 63, 32)           128
#  chNormalization)
#
#  max_pooling1d_4 (MaxPooling  (None, 31, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (None, 992)               0
#
#  dense_53 (Dense)            (None, 64)                63552
#
#  batch_normalization_40 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_35 (Dropout)        (None, 64)                0
#
#  dense_54 (Dense)            (None, 32)                2080
#
#  batch_normalization_41 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 32)                0
#
#  dense_55 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 66,800
# Trainable params: 66,544
# Non-trainable params: 256
# _________________________________________________________________
# 146.84200143814087 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1934 - accuracy: 0.9333
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 63, 32)            128
#
#  batch_normalization_42 (Bat  (None, 63, 32)           128
#  chNormalization)
#
#  max_pooling1d_5 (MaxPooling  (None, 31, 32)           0
#  1D)
#
#  flatten_5 (Flatten)         (None, 992)               0
#
#  dense_56 (Dense)            (None, 128)               127104
#
#  batch_normalization_43 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 128)               0
#
#  dense_57 (Dense)            (None, 64)                8256
#
#  batch_normalization_44 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  dense_58 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 137,424
# Trainable params: 136,976
# Non-trainable params: 448
# _________________________________________________________________
# 150.6581094264984 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1647 - accuracy: 0.9333
# 15/15 [==============================] - 0s 1ms/step
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 63, 64)            256
#
#  batch_normalization_45 (Bat  (None, 63, 64)           256
#  chNormalization)
#
#  max_pooling1d_6 (MaxPooling  (None, 31, 64)           0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 29, 32)            6176
#
#  batch_normalization_46 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  max_pooling1d_7 (MaxPooling  (None, 14, 32)           0
#  1D)
#
#  flatten_6 (Flatten)         (None, 448)               0
#
#  dense_59 (Dense)            (None, 64)                28736
#
#  batch_normalization_47 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_39 (Dropout)        (None, 64)                0
#
#  dense_60 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 36,848
# Trainable params: 36,528
# Non-trainable params: 320
# _________________________________________________________________
# 79.23566389083862 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2052 - accuracy: 0.9375
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 63, 64)            256
#
#  batch_normalization_48 (Bat  (None, 63, 64)           256
#  chNormalization)
#
#  max_pooling1d_8 (MaxPooling  (None, 31, 64)           0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 29, 32)            6176
#
#  batch_normalization_49 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  max_pooling1d_9 (MaxPooling  (None, 14, 32)           0
#  1D)
#
#  flatten_7 (Flatten)         (None, 448)               0
#
#  dense_61 (Dense)            (None, 64)                28736
#
#  batch_normalization_50 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_40 (Dropout)        (None, 64)                0
#
#  dense_62 (Dense)            (None, 32)                2080
#
#  batch_normalization_51 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_41 (Dropout)        (None, 32)                0
#
#  dense_63 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 38,544
# Trainable params: 38,160
# Non-trainable params: 384
# _________________________________________________________________
# 122.14478540420532 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1902 - accuracy: 0.9396
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 63, 64)            256
#
#  batch_normalization_52 (Bat  (None, 63, 64)           256
#  chNormalization)
#
#  max_pooling1d_10 (MaxPoolin  (None, 31, 64)           0
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 29, 32)            6176
#
#  batch_normalization_53 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  max_pooling1d_11 (MaxPoolin  (None, 14, 32)           0
#  g1D)
#
#  flatten_8 (Flatten)         (None, 448)               0
#
#  dense_64 (Dense)            (None, 128)               57472
#
#  batch_normalization_54 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_42 (Dropout)        (None, 128)               0
#
#  dense_65 (Dense)            (None, 64)                8256
#
#  batch_normalization_55 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_43 (Dropout)        (None, 64)                0
#
#  dense_66 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 74,352
# Trainable params: 73,776
# Non-trainable params: 576
# _________________________________________________________________
# 145.76541113853455 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2070 - accuracy: 0.9333
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 63, 32)            128
#
#  batch_normalization_56 (Bat  (None, 63, 32)           128
#  chNormalization)
#
#  max_pooling1d_12 (MaxPoolin  (None, 31, 32)           0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 29, 16)            1552
#
#  batch_normalization_57 (Bat  (None, 29, 16)           64
#  chNormalization)
#
#  max_pooling1d_13 (MaxPoolin  (None, 14, 16)           0
#  g1D)
#
#  flatten_9 (Flatten)         (None, 224)               0
#
#  dense_67 (Dense)            (None, 64)                14400
#
#  batch_normalization_58 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_44 (Dropout)        (None, 64)                0
#
#  dense_68 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 17,568
# Trainable params: 17,344
# Non-trainable params: 224
# _________________________________________________________________
# 114.53254079818726 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1832 - accuracy: 0.9438
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (None, 63, 32)            128
#
#  batch_normalization_59 (Bat  (None, 63, 32)           128
#  chNormalization)
#
#  max_pooling1d_14 (MaxPoolin  (None, 31, 32)           0
#  g1D)
#
#  conv1d_15 (Conv1D)          (None, 29, 16)            1552
#
#  batch_normalization_60 (Bat  (None, 29, 16)           64
#  chNormalization)
#
#  max_pooling1d_15 (MaxPoolin  (None, 14, 16)           0
#  g1D)
#
#  flatten_10 (Flatten)        (None, 224)               0
#
#  dense_69 (Dense)            (None, 64)                14400
#
#  batch_normalization_61 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_45 (Dropout)        (None, 64)                0
#
#  dense_70 (Dense)            (None, 32)                2080
#
#  batch_normalization_62 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_46 (Dropout)        (None, 32)                0
#
#  dense_71 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 19,264
# Trainable params: 18,976
# Non-trainable params: 288
# _________________________________________________________________
# 138.30906629562378 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1913 - accuracy: 0.9292
# 15/15 [==============================] - 0s 2ms/step
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_16 (Conv1D)          (None, 63, 32)            128
#
#  batch_normalization_63 (Bat  (None, 63, 32)           128
#  chNormalization)
#
#  max_pooling1d_16 (MaxPoolin  (None, 31, 32)           0
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 29, 16)            1552
#
#  batch_normalization_64 (Bat  (None, 29, 16)           64
#  chNormalization)
#
#  max_pooling1d_17 (MaxPoolin  (None, 14, 16)           0
#  g1D)
#
#  flatten_11 (Flatten)        (None, 224)               0
#
#  dense_72 (Dense)            (None, 128)               28800
#
#  batch_normalization_65 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_47 (Dropout)        (None, 128)               0
#
#  dense_73 (Dense)            (None, 64)                8256
#
#  batch_normalization_66 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_48 (Dropout)        (None, 64)                0
#
#  dense_74 (Dense)            (None, 16)                1040
#
# =================================================================
# Total params: 40,736
# Trainable params: 40,256
# Non-trainable params: 480
# _________________________________________________________________
# 184.50859451293945 seconds
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2152 - accuracy: 0.9354
# 15/15 [==============================] - 0s 2ms/step
